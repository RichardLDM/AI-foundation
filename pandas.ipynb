# %% [markdown]
# <a href="https://colab.research.google.com/github/RichardLDM/AI-foundation/blob/main/pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
print(pd.__version__)
# Out:
# 2.2.2

# %%
mydataset = {
    "cars": ["BMW", "Volvo", "Ford", "Tesla", "Ferrari", "Ford", 'BMW'],
    "counts": [3, 7, 2, 8, 1, 9, 3]
}
print(mydataset)
print("====="*11)

df = pd.DataFrame(mydataset)
print(df)
# Out:
# {'cars': ['BMW', 'Volvo', 'Ford', 'Tesla', 'Ferrari', 'Ford', 'BMW'], 'counts': [3, 7, 2, 8, 1, 9, 3]}
# ...
#       cars  counts
# 0      BMW       3
# 1    Volvo       7
# 2     Ford       2
# 3    Tesla       8
# 4  Ferrari       1
# 5     Ford       9
# 6      BMW       3

# %%
df.head() # default 5 row
# Out:
#       cars  counts
# 0      BMW       3
# 1    Volvo       7
# 2     Ford       2
# 3    Tesla       8
# 4  Ferrari       1

# %%
df.tail() # default 5 row
# Out:
#       cars  counts
# 2     Ford       2
# 3    Tesla       8
# 4  Ferrari       1
# 5     Ford       9
# 6      BMW       3

# %%
df.shape
# Out:
# (7, 2)

# %%
df.columns
# Out:
# Index(['cars', 'counts'], dtype='object')

# %%
df.dtypes
# Out:
# cars      object
# counts     int64
# dtype: object

# %%
print(df)
# Out:
#       cars  counts
# 0      BMW       3
# 1    Volvo       7
# 2     Ford       2
# 3    Tesla       8
# 4  Ferrari       1
# 5     Ford       9
# 6      BMW       3

# %%
df.describe() #default numerical columns only # include="all"
# Out:
#          counts
# count  7.000000
# mean   4.714286
# std    3.199702
# min    1.000000
# 25%    2.500000
# 50%    3.000000
# 75%    7.500000
# max    9.000000

# %%
df.iloc[2:] # -1, 1:4
# Out:
#       cars  counts
# 2     Ford       2
# 3    Tesla       8
# 4  Ferrari       1
# 5     Ford       9
# 6      BMW       3

# %%
df.loc[:, "counts"] # :, 2, cars, 2:5
# Out:
# 0    3
# 1    7
# 2    2
# 3    8
# 4    1
# 5    9
# 6    3
# Name: counts, dtype: int64

# %%
df[df["counts"] != 3] # df["counts"] > 3, df[df["cars"] == "BMW"]
# Out:
#       cars  counts
# 1    Volvo       7
# 2     Ford       2
# 3    Tesla       8
# 4  Ferrari       1
# 5     Ford       9

# %%
# df.mean(numeric_only=True)
df["counts"].mean()
# Out:
# np.float64(4.714285714285714)

# %%
df.sum()
# Out:
# cars      BMWVolvoFordTeslaFerrariFordBMW
# counts                                 33
# dtype: object

# %%
df.min()
# Out:
# cars      BMW
# counts      1
# dtype: object

# %%
df.max()
# Out:
# cars      Volvo
# counts        9
# dtype: object

# %%
df.median(numeric_only=True)
# Out:
# counts    3.0
# dtype: float64

# %%
df.count()
# Out:
# cars      7
# counts    7
# dtype: int64

# %%
df.std(numeric_only=True)
# Out:
# counts    3.199702
# dtype: float64

# %%
data_with_missing = {
    "cars": ["BMW", "Volvo", None, "Tesla", None, "Ford", 'BMW'],
    "counts": [3, 7, None, 8, 1, 9, None],
}

df_missing = pd.DataFrame(data_with_missing)
print(df_missing)
# Out:
#     cars  counts
# 0    BMW     3.0
# 1  Volvo     7.0
# 2   None     NaN
# 3  Tesla     8.0
# 4   None     1.0
# 5   Ford     9.0
# 6    BMW     NaN

# %%
df_missing.isnull().sum()
# Out:
# cars      2
# counts    2
# dtype: int64

# %%
print(df)
# Out:
#       cars  counts
# 0      BMW       3
# 1    Volvo       7
# 2     Ford       2
# 3    Tesla       8
# 4  Ferrari       1
# 5     Ford       9
# 6      BMW       3

# %%
df_missing.dropna(subset=['counts']) # df_missing.dropna(how="all"), df_missing.dropna(axis=1)
# Out:
#     cars  counts
# 0    BMW     3.0
# 1  Volvo     7.0
# 3  Tesla     8.0
# 4   None     1.0
# 5   Ford     9.0

# %%
df_missing.fillna({"cars": "unkwon", 'counts': 0}) # df_missing.fillna("unknown"), df_missing.fillna(0)
# Out:
#      cars  counts
# 0     BMW     3.0
# 1   Volvo     7.0
# 2  unkwon     0.0
# 3   Tesla     8.0
# 4  unkwon     1.0
# 5    Ford     9.0
# 6     BMW     0.0

# %%
df = pd.read_csv("Titanic-Dataset.csv")
# print(df)
# df.head(30)
df.tail()

# df = pd.read_xlsx("Titanic-Dataset.xlsx")
# df = pd.read_json("Titanic-Dataset.json")
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df.to_excel("output.xlsx")

# %%
# df = pd.read_xlsx("output.xlsx")
# print(df)
# df.head(30)
df.tail()

# df = pd.read_json("Titanic-Dataset.json")
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
# Series => 1D
cars = pd.Series(["BMW", "Volvo", "Ford", "Tesla", "Ferrari", "Ford", 'BMW'])
print(cars)
# Out:
# 0        BMW
# 1      Volvo
# 2       Ford
# 3      Tesla
# 4    Ferrari
# 5       Ford
# 6        BMW
# dtype: object

# %%
cars_series = data_with_missing["cars"]
print(cars_series)
# Out:
# ['BMW', 'Volvo', None, 'Tesla', None, 'Ford', 'BMW']
